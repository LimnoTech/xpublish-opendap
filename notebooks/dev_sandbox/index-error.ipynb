# %%
import subprocess
import xarray as xr
import time

# %%
url = 'http://127.0.0.1:8000/datasets/ds/opendap'

# %%
xr.open_dataset(
    url,
    engine='netcdf4',
    decode_times=False
)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# File c:\Users\sjordan\Anaconda3\envs\catalog_to_xpublish_dev\Lib\site-packages\xarray\backends\netCDF4_.py:113, in NetCDF4ArrayWrapper._getitem(self, key)
#     112         original_array = self.get_array(needs_lock=False)
# --> 113         array = getitem(original_array, key)
#     114 except IndexError:
#     115     # Catch IndexError in netCDF4 and return a more informative
#     116     # error message.  This is most often called when an unsorted
#     117     # indexer is used before the data is loaded from disk.
#
# File c:\Users\sjordan\Anaconda3\envs\catalog_to_xpublish_dev\Lib\site-packages\xarray\backends\common.py:151, in robust_getitem(array, key, catch, max_retries, initial_delay)
#     150 try:
# --> 151     return array[key]
#     152 except catch:
#
# ...
